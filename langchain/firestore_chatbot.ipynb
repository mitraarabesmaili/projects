# %%
# !pip install --quiet langchain langchain-google-firestore google-cloud-firestore
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 1.3 MB/s eta 0:00:00

# %% [markdown]
# """
# This script demonstrates how to build a persistent chat interface using LangChain with Firestore
# as the message history backend and an OpenAI-compatible model for conversational AI.
#
# Environment Variables Required:
# - GOOGLE_APPLICATION_CREDENTIALS: Path to Google service account credentials JSON file.
# - PROJECT_ID: Firebase/Google Cloud project ID.
# - SESSION_ID: Unique session identifier for the chat history (e.g., user ID).
# - COLLECTION_NAME: Firestore collection name to store chat messages.
# """

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0a91d202-41a0-4ab6-aff0-1e1c1b6d689b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a91d202-41a0-4ab6-aff0-1e1c1b6d689b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
from langchain_google_firestore import FirestoreChatMessageHistory
from langchain.memory import ConversationBufferMemory
from langchain.chat_models import ChatOpenAI

service_account_path = "test-lch-firebase-adminsdk-fbsvc-cb8bd75f0b.json"


os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = service_account_path


PROJECT_ID = "test-lch"
SESSION_ID = "user1"
COLLECTION_NAME = "chat_history"


from google.cloud import firestore
client = firestore.Client(project=PROJECT_ID)


chat_history = FirestoreChatMessageHistory(
    session_id=SESSION_ID,
    collection=COLLECTION_NAME,
    client=client,
)


print("Chat History Initialized.")
print("Current Chat History:", chat_history.messages)

# Initialize Chat Model
# model = ChatOpenAI()
model = ChatOpenAI(
    model_name = "gpt-3.5-turbo",
    openai_api_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjIwNjIyOTkzMDEsImp0aSI6ImMyMDEzNWM0LWZjMjUtNDE4Zi05MjE2LTM1ZTJmNGNkNWViNyIsImlhdCI6MTc0NjkzOTMwMSwiaXNzIjoiaHR0cHM6Ly9naWxhcy5pbyIsIm5iZiI6MTc0NjkzOTMwMSwic3ViIjoiMTA0MjE3MzAxMTE2NjE0MzkxNDUxIiwic2NvcGUiOiJbXCJhcGlcIl0ifQ.fBdZUUM2pRGztc25tU9u3aei5U-MACq4VB6q4faDPr8",
    openai_api_base = "https://api.gilas.io/v1/"
)
print("Start chatting with the AI. Type 'exit' to quit.")

while True:
    human_input = input("User: ")
    if human_input.lower() == "exit":
        break

    chat_history.add_user_message(human_input)

    ai_response = model.invoke(chat_history.messages)
    chat_history.add_ai_message(ai_response.content)

    print(f"AI: {ai_response.content}")


# memory = ConversationBufferMemory(chat_memory=chat_history)


# llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)


# from langchain.chains import ConversationChain

# conversation = ConversationChain(
#     llm=llm,
#     memory=memory,
#     verbose=True
# )

# conversation.predict(input="سلام، حالت چطوره؟")
# Out:
# Chat History Initialized.
# Current Chat History: []
# Start chatting with the AI. Type 'exit' to quit.
# User: user1
# AI: Hello! How can I assist you today?
# User: how ai works in my daily tasks
# AI: Artificial intelligence (AI) can assist you in your daily tasks in various ways. Here are a few examples:
#
# 1. Personalized recommendations: AI algorithms can analyze your preferences and behavior to provide personalized recommendations for products, services, movies, music, and more.
#
# 2. Virtual assistants: Virtual assistants like Siri, Alexa, and Google Assistant use AI to understand and respond to your voice commands, helping you with tasks like setting reminders, sending messages, and answering questions.
#
# 3. Smart home devices: AI-powered smart home devices can automate tasks like adjusting the thermostat, turning on lights, and locking doors based on your preferences and routines.
#
# ...
